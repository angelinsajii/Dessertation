# %%
import pandas as pd

# %%
#loading data
df = pd.read_csv('/content/NEW DATA.csv')

# %%
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
#printing the data
df.columns
# Out:
# Index(['index', 'pweight', 'cntry', 'nwspol', 'netusoft', 'netustm', 'polintr',
#        'trstsci', 'stfedu', 'stfhlth', 'gincdif', 'happy', 'crmvct', 'health',
#        'rlgblg', 'rlgblge', 'rlgdgr', 'dscretn', 'dscrage', 'dscrgnd',
#        'dscrsex', 'dscrdsb', 'cntbrthd', 'feethngr', 'fbrncntc', 'mbrncntc',
#        'gvctzpv', 'grdfinc', 'rghmgprc', 'cttresac', 'gvctzpvc', 'grdfincc',
#        'gndr', 'yrbrn', 'agea', 'rshpsts', 'dvrcdeva', 'marsts', 'chldhhe',
#        'edulvlb', 'eduyrs', 'pdjobev', 'emplrel', 'hinctnta', 'hincfel',
#        'edulvlpb', 'emprelp', 'edulvlfb', 'edulvlmb', 'agepnt'],
#       dtype='object')

# %%
#reset  index the values
#df.reset_index(inplace=True)

# %%
#check null values
df.isnull().sum()
# Out:
# pweight       2
# cntry         2
# nwspol        2
# netusoft      2
# netustm       2
# polintr       2
# trstsci       2
# stfedu        2
# stfhlth       2
# gincdif       2
# happy         2
# crmvct        2
# health        2
# rlgblg        2
# rlgblge       2
# rlgdgr        2
# dscretn       2
# dscrage       2
# dscrgnd       2
# dscrsex       2
# dscrdsb       2
# cntbrthd      2
# feethngr      2
# fbrncntc      2
# mbrncntc      2
# gvctzpv       2
# grdfinc       2
# rghmgprc      2
# cttresac      2
# gvctzpvc      2
# grdfincc      2
# gndr          2
# yrbrn         2
# agea        122
# rshpsts       2
# dvrcdeva      2
# marsts        2
# chldhhe       2
# edulvlb       2
# eduyrs        2
# pdjobev       2
# emplrel       2
# hinctnta      2
# hincfel       2
# edulvlpb      2
# emprelp       2
# edulvlfb      2
# edulvlmb      2
# agepnt        2
# dtype: int64

# %%
#not in the report
df['agea']
# Out:
# 0        76.0
# 1        43.0
# 2        50.0
# 3        51.0
# 4        70.0
#          ...
# 18057    48.0
# 18058    49.0
# 18059    36.0
# 18060     NaN
# 18061     NaN
# Name: agea, Length: 18062, dtype: float64

# %%
#removing the null values
df.dropna(axis=0, how="any", inplace=True)

# %%
#reseting the index numbers
df.reset_index(inplace=True)

# %%
#printing the data frame after removing the null values
df
# Out:
#        index   pweight cntry  nwspol  netusoft  netustm  polintr  trstsci  \
# 0          0  0.217716    BG    80.0       1.0   6666.0      4.0      6.0
# 1          1  0.217716    BG    63.0       5.0    180.0      1.0     10.0
# 2          2  0.217716    BG   390.0       5.0    405.0      3.0      6.0
# 3          3  0.217716    BG    60.0       5.0     80.0      4.0      3.0
# 4          4  0.217716    BG   120.0       5.0    120.0      1.0      3.0
# ...      ...       ...   ...     ...       ...      ...      ...      ...
# 17935  18055  0.323800    SK   120.0       2.0   6666.0      4.0     10.0
# 17936  18056  0.323800    SK    90.0       4.0    120.0      2.0     10.0
# 17937  18057  0.323800    SK    30.0       2.0   6666.0      2.0      4.0
# 17938  18058  0.323800    SK    30.0       5.0     90.0      4.0      9.0
# 17939  18059  0.323800    SK    30.0       3.0   6666.0      4.0      8.0
#
#        stfedu  stfhlth  ...  eduyrs  pdjobev  emplrel  hinctnta  hincfel  \
# ...

# %%
#checking th e null values again after dropping
df.isnull().sum()
# Out:
# index       0
# pweight     0
# cntry       0
# nwspol      0
# netusoft    0
# netustm     0
# polintr     0
# trstsci     0
# stfedu      0
# stfhlth     0
# gincdif     0
# happy       0
# crmvct      0
# health      0
# rlgblg      0
# rlgblge     0
# rlgdgr      0
# dscretn     0
# dscrage     0
# dscrgnd     0
# dscrsex     0
# dscrdsb     0
# cntbrthd    0
# feethngr    0
# fbrncntc    0
# mbrncntc    0
# gvctzpv     0
# grdfinc     0
# rghmgprc    0
# cttresac    0
# gvctzpvc    0
# grdfincc    0
# gndr        0
# yrbrn       0
# agea        0
# rshpsts     0
# dvrcdeva    0
# marsts      0
# chldhhe     0
# edulvlb     0
# eduyrs      0
# pdjobev     0
# emplrel     0
# hinctnta    0
# hincfel     0
# edulvlpb    0
# emprelp     0
# edulvlfb    0
# edulvlmb    0
# agepnt      0
# dtype: int64

# %%
x=df.drop(columns=['edulvlb'])

# %%
y=df['edulvlb']

# %%
x
# Out:
#        index   pweight cntry  nwspol  netusoft  netustm  polintr  trstsci  \
# 0          0  0.217716    BG    80.0       1.0   6666.0      4.0      6.0
# 1          1  0.217716    BG    63.0       5.0    180.0      1.0     10.0
# 2          2  0.217716    BG   390.0       5.0    405.0      3.0      6.0
# 3          3  0.217716    BG    60.0       5.0     80.0      4.0      3.0
# 4          4  0.217716    BG   120.0       5.0    120.0      1.0      3.0
# ...      ...       ...   ...     ...       ...      ...      ...      ...
# 17935  18055  0.323800    SK   120.0       2.0   6666.0      4.0     10.0
# 17936  18056  0.323800    SK    90.0       4.0    120.0      2.0     10.0
# 17937  18057  0.323800    SK    30.0       2.0   6666.0      2.0      4.0
# 17938  18058  0.323800    SK    30.0       5.0     90.0      4.0      9.0
# 17939  18059  0.323800    SK    30.0       3.0   6666.0      4.0      8.0
#
#        stfedu  stfhlth  ...  eduyrs  pdjobev  emplrel  hinctnta  hincfel  \
# ...

# %%
# Get categorical and numerical variables

numCols = x.select_dtypes("number").columns
catCols = x.select_dtypes("object").columns
numCols= list(set(numCols))
catCols= list(set(catCols))

# %%
numCols
# Out:
# ['edulvlpb',
#  'gvctzpvc',
#  'gndr',
#  'dscrsex',
#  'happy',
#  'polintr',
#  'dscrage',
#  'edulvlfb',
#  'dscrgnd',
#  'gvctzpv',
#  'dvrcdeva',
#  'dscretn',
#  'gincdif',
#  'rlgblg',
#  'netusoft',
#  'marsts',
#  'agepnt',
#  'rghmgprc',
#  'chldhhe',
#  'index',
#  'grdfinc',
#  'emplrel',
#  'grdfincc',
#  'stfhlth',
#  'feethngr',
#  'crmvct',
#  'stfedu',
#  'edulvlmb',
#  'eduyrs',
#  'agea',
#  'nwspol',
#  'dscrdsb',
#  'cttresac',
#  'rshpsts',
#  'pdjobev',
#  'rlgblge',
#  'health',
#  'hinctnta',
#  'trstsci',
#  'netustm',
#  'hincfel',
#  'pweight',
#  'rlgdgr',
#  'yrbrn',
#  'emprelp']

# %%
catCols
# Out:
# ['mbrncntc', 'cntbrthd', 'fbrncntc', 'cntry']

# %%
df['cntry']
# Out:
# 0        BG
# 1        BG
# 2        BG
# 3        BG
# 4        BG
#          ..
# 17935    SK
# 17936    SK
# 17937    SK
# 17938    SK
# 17939    SK
# Name: cntry, Length: 17940, dtype: object

# %%
df['fbrncntc']
# Out:
# 0        6666
# 1        6666
# 2        6666
# 3        6666
# 4        6666
#          ...
# 17935    6666
# 17936    6666
# 17937    6666
# 17938    6666
# 17939    6666
# Name: fbrncntc, Length: 17940, dtype: object

# %%
df['cntbrthd']
# Out:
# 0        6666
# 1        6666
# 2        6666
# 3        6666
# 4        6666
#          ...
# 17935    6666
# 17936    6666
# 17937    6666
# 17938    6666
# 17939    6666
# Name: cntbrthd, Length: 17940, dtype: object

# %%
df['mbrncntc']
# Out:
# 0        6666
# 1        6666
# 2        6666
# 3        6666
# 4        6666
#          ...
# 17935    6666
# 17936    6666
# 17937    6666
# 17938    6666
# 17939    6666
# Name: mbrncntc, Length: 17940, dtype: object

# %%
x=x.drop(columns=catCols)

# %%
x
# Out:
#        index   pweight  nwspol  netusoft  netustm  polintr  trstsci  stfedu  \
# 0          0  0.217716    80.0       1.0   6666.0      4.0      6.0     3.0
# 1          1  0.217716    63.0       5.0    180.0      1.0     10.0     8.0
# 2          2  0.217716   390.0       5.0    405.0      3.0      6.0     3.0
# 3          3  0.217716    60.0       5.0     80.0      4.0      3.0     1.0
# 4          4  0.217716   120.0       5.0    120.0      1.0      3.0     2.0
# ...      ...       ...     ...       ...      ...      ...      ...     ...
# 17935  18055  0.323800   120.0       2.0   6666.0      4.0     10.0    99.0
# 17936  18056  0.323800    90.0       4.0    120.0      2.0     10.0     6.0
# 17937  18057  0.323800    30.0       2.0   6666.0      2.0      4.0     5.0
# 17938  18058  0.323800    30.0       5.0     90.0      4.0      9.0     7.0
# 17939  18059  0.323800    30.0       3.0   6666.0      4.0      8.0     7.0
#
# ...

# %%
catCols = x.select_dtypes("object").columns
catCols= list(set(catCols))

# %%
y
# Out:
# 0         323.0
# 1         620.0
# 2         720.0
# 3         313.0
# 4         720.0
#           ...
# 17935     321.0
# 17936     323.0
# 17937     720.0
# 17938     720.0
# 17939    9999.0
# Name: edulvlb, Length: 17940, dtype: float64

# %%
y=y.astype(int)

# %%
y.unique()
# Out:
# array([ 323,  620,  720,  313,    0,  610,  213,  222,  800,  113,  421,
#         229, 5555,  520,  321,  423, 8888,  710, 7777,  510,  413, 9999,
#         223,  221,  422])

# %%
y[1]
# Out:
# 620

# %%
y[0]
# Out:
# 323

# %%
y[523]
# Out:
# 213

# %%
y[524]
# Out:
# 313

# %%
y[525]
# Out:
# 313

# %%
for i in range(len(y)):
  if (y[i]==323):
    print(y[i])
# Out:
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# 323
# ...

# %%
for i in range(len(y)):
  if (y[i]==323):
    y[i]='Vocational ISCED 3A access upper tier ISCED 5A all 5'
  if (y[i]==620):
    y[i]='ISCED 5A'
  if(y[i]==720):
    y[i]='ISCED 5A'
  if(y[i]==313):
    y[i]='General ISCED 3A access upper tier ISCED 5A all 5'
  if(y[i]==0):
    y[i]='Not completed ISCED level 1'
  if(y[i]==610):
    y[i]='ISCED 5A'
  if(y[i]==213):
    y[i]='General ISCED 2A access ISCED 3A general all 3'
  if(y[i]==222):
    y[i]='Vocational ISCED 2A 2B access ISCED 3 vocational'
  if(y[i]==800):
    y[i]='ISCED 6 doctoral degree'
  if(y[i]==113):
    y[i]='ISCED 1 completed primary education'
  if(y[i]==421):
    y[i]='ISCED 4 programmes without access ISCED 5'
  if(y[i]==229):
    y[i]='Vocational ISCED 3C 2 years no access ISCED 5'
  if(y[i]==520):
    y[i]='ISCED 5B short advanced vocational qualifications'
  if(y[i]==321):
    y[i]='Vocational ISCED 3C 2 years no access ISCED 5'
  if(y[i]==423):
    y[i]='Vocational ISCED 4A access upper tier ISCED 5A all 5'
  if(y[i]==8888):
    y[i]='Dont know'
  if(y[i]==710):
    y[i]='ISCED 5A long master equivalent from lower tier tertiary'
  if(y[i]==7777):
    y[i]='Refusal'
  if(y[i]==510):
    y[i]='ISCED 5A short intermediate academic general tertiary below bachelor'
  if(y[i]==413):
    y[i]='General ISCED 4A access upper tier ISCED 5A all 5'
  if(y[i]==9999):
    y[i]='No answer'
  if(y[i]==223):
    y[i]='Vocational ISCED 2 access ISCED 3 general all'
  if(y[i]==221):
    y[i]='Vocational ISCED 2C 2 years no access ISCED 3'
  if(y[i]==422):
    y[i]='Vocational ISCED 4A 4B access ISCED 5B lower tier 5A'

# %%
x
# Out:
#        index   pweight  nwspol  netusoft  netustm  polintr  trstsci  stfedu  \
# 0          0  0.217716    80.0       1.0   6666.0      4.0      6.0     3.0
# 1          1  0.217716    63.0       5.0    180.0      1.0     10.0     8.0
# 2          2  0.217716   390.0       5.0    405.0      3.0      6.0     3.0
# 3          3  0.217716    60.0       5.0     80.0      4.0      3.0     1.0
# 4          4  0.217716   120.0       5.0    120.0      1.0      3.0     2.0
# ...      ...       ...     ...       ...      ...      ...      ...     ...
# 17935  18055  0.323800   120.0       2.0   6666.0      4.0     10.0    99.0
# 17936  18056  0.323800    90.0       4.0    120.0      2.0     10.0     6.0
# 17937  18057  0.323800    30.0       2.0   6666.0      2.0      4.0     5.0
# 17938  18058  0.323800    30.0       5.0     90.0      4.0      9.0     7.0
# 17939  18059  0.323800    30.0       3.0   6666.0      4.0      8.0     7.0
#
# ...

# %%
y
# Out:
# 0        Vocational ISCED 3A access upper tier ISCED 5A...
# 1                                                 ISCED 5A
# 2                                                 ISCED 5A
# 3        General ISCED 3A access upper tier ISCED 5A all 5
# 4                                                 ISCED 5A
#                                ...
# 17935        Vocational ISCED 3C 2 years no access ISCED 5
# 17936    Vocational ISCED 3A access upper tier ISCED 5A...
# 17937                                             ISCED 5A
# 17938                                             ISCED 5A
# 17939                                            No answer
# Name: edulvlb, Length: 17940, dtype: object

# %%
y=y.astype(str)

# %%
y.unique()
# Out:
# array(['Vocational ISCED 3A access upper tier ISCED 5A all 5', 'ISCED 5A',
#        'General ISCED 3A access upper tier ISCED 5A all 5',
#        'Not completed ISCED level 1',
#        'General ISCED 2A access ISCED 3A general all 3',
#        'Vocational ISCED 2A 2B access ISCED 3 vocational',
#        'ISCED 6 doctoral degree', 'ISCED 1 completed primary education',
#        'ISCED 4 programmes without access ISCED 5',
#        'Vocational ISCED 3C 2 years no access ISCED 5', '5555',
#        'ISCED 5B short advanced vocational qualifications',
#        'Vocational ISCED 4A access upper tier ISCED 5A all 5',
#        'Dont know',
#        'ISCED 5A long master equivalent from lower tier tertiary',
#        'Refusal',
#        'ISCED 5A short intermediate academic general tertiary below bachelor',
#        'General ISCED 4A access upper tier ISCED 5A all 5', 'No answer',
#        'Vocational ISCED 2 access ISCED 3 general all',
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(y)
# Out:
# LabelEncoder()

# %%
y=le.transform(y)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)

# %%
le.classes_
# Out:
# array(['5555', 'Dont know',
#        'General ISCED 2A access ISCED 3A general all 3',
#        'General ISCED 3A access upper tier ISCED 5A all 5',
#        'General ISCED 4A access upper tier ISCED 5A all 5',
#        'ISCED 1 completed primary education',
#        'ISCED 4 programmes without access ISCED 5', 'ISCED 5A',
#        'ISCED 5A long master equivalent from lower tier tertiary',
#        'ISCED 5A short intermediate academic general tertiary below bachelor',
#        'ISCED 5B short advanced vocational qualifications',
#        'ISCED 6 doctoral degree', 'No answer',
#        'Not completed ISCED level 1', 'Refusal',
#        'Vocational ISCED 2 access ISCED 3 general all',
#        'Vocational ISCED 2A 2B access ISCED 3 vocational',
#        'Vocational ISCED 2C 2 years no access ISCED 3',
#        'Vocational ISCED 3A access upper tier ISCED 5A all 5',
#        'Vocational ISCED 3C 2 years no access ISCED 5',
# ...

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(k_neighbors=2)
X_train, y_train = sm.fit_resample(X_train, y_train)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler.fit(X_train)
X_train = scaler.transform(X_train)

# %%
X_train
# Out:
# array([[-0.58475876, -0.4270453 , -0.23010144, ...,  2.42127454,
#          2.96399396, -1.38433287],
#        [ 1.40395581, -0.39819862, -0.19942266, ..., -0.45115756,
#         -0.37370052, -1.34488606],
#        [-0.06589646,  2.21919646, -0.21987518, ..., -0.48736891,
#         -0.37370052, -1.3950911 ],
#        ...,
#        [-0.43910642, -0.4270453 , -0.12049147, ..., -0.52208308,
#         -0.37170265,  0.79958605],
#        [ 0.82231234, -0.58791463, -0.12827153, ...,  2.42127454,
#         -0.4046099 ,  0.23143855],
#        [ 1.43640885, -0.39819862, -0.20485654, ..., -0.45048698,
#         -0.37578222, -1.29921986]])

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn import svm
clf = svm.SVC()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
cf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 8))
ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues',fmt="d")

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Category')
ax.set_ylabel('Actual Category ');


## Display the visualization of the Confusion Matrix.
plt.show()
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.50      0.20      0.29         5
#            2       0.40      0.41      0.40       522
#            3       0.29      0.18      0.23       674
#            4       0.00      0.00      0.00         3
#            5       0.26      0.36      0.30       162
#            6       0.09      0.30      0.14        86
#            7       0.61      0.43      0.50      1199
#            8       0.08      0.17      0.11        77
#            9       0.00      0.00      0.00        19
#           10       0.14      0.27      0.18       239
#           11       0.12      0.22      0.15        50
#           12       0.12      0.20      0.15         5
#           13       0.00      0.00      0.00        20
#           14       0.00      0.00      0.00        10
#           15       0.03      0.06      0.04        16
# ...

# %%
# Decision Tree model 
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier()
# fit the model 
tree.fit(X_train, y_train)

#predicting the target value from the model for the samples
y_test_tree = tree.predict(X_test)

# %%
importance=tree.feature_importances_
from matplotlib import pyplot
# summarize feature importance
for i,v in enumerate(importance):
 print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.08871
# Feature: 1, Score: 0.08296
# Feature: 2, Score: 0.05498
# Feature: 3, Score: 0.01837
# Feature: 4, Score: 0.00832
# Feature: 5, Score: 0.01938
# Feature: 6, Score: 0.01240
# Feature: 7, Score: 0.01469
# Feature: 8, Score: 0.01681
# Feature: 9, Score: 0.01189
# Feature: 10, Score: 0.01481
# Feature: 11, Score: 0.01254
# Feature: 12, Score: 0.00319
# Feature: 13, Score: 0.01232
# Feature: 14, Score: 0.02492
# Feature: 15, Score: 0.00624
# Feature: 16, Score: 0.01237
# Feature: 17, Score: 0.00110
# Feature: 18, Score: 0.00033
# Feature: 19, Score: 0.00452
# Feature: 20, Score: 0.02731
# Feature: 21, Score: 0.00241
# Feature: 22, Score: 0.00223
# Feature: 23, Score: 0.02616
# Feature: 24, Score: 0.00968
# Feature: 25, Score: 0.01459
# Feature: 26, Score: 0.02146
# Feature: 27, Score: 0.01409
# Feature: 28, Score: 0.01426
# Feature: 29, Score: 0.01281
# Feature: 30, Score: 0.01651
# Feature: 31, Score: 0.01208
# Feature: 32, Score: 0.00398
# ...

# %%
cf_matrix = confusion_matrix(y_test, y_test_tree)
plt.figure(figsize=(8, 8))
ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues',fmt="d")

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Category')
ax.set_ylabel('Actual Category ');


## Display the visualization of the Confusion Matrix.
plt.show()
print(classification_report(y_test, y_test_tree))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-7f49b87c6ae1> in <module>
# ----> 1 cf_matrix = confusion_matrix(y_test, y_test_tree)
#       2 plt.figure(figsize=(8, 8))
#       3 ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues',fmt="d")
#       4
#       5 ax.set_title('Seaborn Confusion Matrix with labels\n\n');
#
# NameError: name 'y_test_tree' is not defined

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(X_train, y_train)

#predicting the target value from the model for the samples
y_test_xgb = model.predict(X_test)

# %%
model
# Out:
# XGBClassifier()

# %%
import matplotlib.pyplot 
effect=model.feature_importances_
 
col_names =list(x.columns)
from matplotlib import pyplot
for i,v in enumerate(effect):
  # print('Feature: %0d, Score: %.5f' %(i,v))
  print('Feature: {}, Score: {:.5f}'.format(col_names[i],v))
pyplot.bar([x for x in range(len(effect))],effect)
pyplot.show
# Out:
# Feature: index, Score: 0.05174
# Feature: pweight, Score: 0.06141
# Feature: nwspol, Score: 0.01064
# Feature: netusoft, Score: 0.01801
# Feature: netustm, Score: 0.02541
# Feature: polintr, Score: 0.01657
# Feature: trstsci, Score: 0.04515
# Feature: stfedu, Score: 0.01355
# Feature: stfhlth, Score: 0.00632
# Feature: gincdif, Score: 0.01794
# Feature: happy, Score: 0.00674
# Feature: crmvct, Score: 0.01458
# Feature: health, Score: 0.01312
# Feature: rlgblg, Score: 0.03175
# Feature: rlgblge, Score: 0.00796
# Feature: rlgdgr, Score: 0.01416
# Feature: dscretn, Score: 0.00653
# Feature: dscrage, Score: 0.00262
# Feature: dscrgnd, Score: 0.04445
# Feature: dscrsex, Score: 0.01933
# Feature: dscrdsb, Score: 0.04520
# Feature: feethngr, Score: 0.00717
# Feature: gvctzpv, Score: 0.01349
# Feature: grdfinc, Score: 0.01499
# Feature: rghmgprc, Score: 0.01974
# Feature: cttresac, Score: 0.04424
# Feature: gvctzpvc, Score: 0.00735
# Feature: grdfincc, Score: 0.01170
# ...

# %%
import matplotlib.pyplot 
effect=model.feature_importances_

from matplotlib import pyplot
for i,v in enumerate(effect):
  print('Feature: %0d, Score: %.5f' %(i,v))
pyplot.bar([x for x in range(len(effect))],effect)
pyplot.show
# Out:
# Feature: 0, Score: 0.05234
# Feature: 1, Score: 0.00000
# Feature: 2, Score: 0.05921
# Feature: 3, Score: 0.01009
# Feature: 4, Score: 0.01750
# Feature: 5, Score: 0.02260
# Feature: 6, Score: 0.01857
# Feature: 7, Score: 0.02624
# Feature: 8, Score: 0.01303
# Feature: 9, Score: 0.00564
# Feature: 10, Score: 0.01503
# Feature: 11, Score: 0.00950
# Feature: 12, Score: 0.01442
# Feature: 13, Score: 0.01548
# Feature: 14, Score: 0.04018
# Feature: 15, Score: 0.00868
# Feature: 16, Score: 0.01597
# Feature: 17, Score: 0.00737
# Feature: 18, Score: 0.00313
# Feature: 19, Score: 0.05724
# Feature: 20, Score: 0.02279
# Feature: 21, Score: 0.03291
# Feature: 22, Score: 0.00787
# Feature: 23, Score: 0.01421
# Feature: 24, Score: 0.01428
# Feature: 25, Score: 0.01626
# Feature: 26, Score: 0.03847
# Feature: 27, Score: 0.00778
# Feature: 28, Score: 0.01227
# Feature: 29, Score: 0.02365
# Feature: 30, Score: 0.02377
# Feature: 31, Score: 0.02180
# Feature: 32, Score: 0.01640
# ...

# %%
# print(len(list(x.columns)))

X_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ae2da0afcf65> in <module>
#       1 # print(len(list(x.columns)))
#       2
# ----> 3 X_train
#
# NameError: name 'X_train' is not defined

# %%
x.columns
# Out:
# Index(['index', 'pweight', 'nwspol', 'netusoft', 'netustm', 'polintr',
#        'trstsci', 'stfedu', 'stfhlth', 'gincdif', 'happy', 'crmvct', 'health',
#        'rlgblg', 'rlgblge', 'rlgdgr', 'dscretn', 'dscrage', 'dscrgnd',
#        'dscrsex', 'dscrdsb', 'feethngr', 'gvctzpv', 'grdfinc', 'rghmgprc',
#        'cttresac', 'gvctzpvc', 'grdfincc', 'gndr', 'yrbrn', 'agea', 'rshpsts',
#        'dvrcdeva', 'marsts', 'chldhhe', 'eduyrs', 'pdjobev', 'emplrel',
#        'hinctnta', 'hincfel', 'edulvlpb', 'emprelp', 'edulvlfb', 'edulvlmb',
#        'agepnt'],
#       dtype='object')

# %%
cf_matrix = confusion_matrix(y_test, y_test_xgb)
plt.figure(figsize=(8, 8))
ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues',fmt="d")

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Category')
ax.set_ylabel('Actual Category ');


## Display the visualization of the Confusion Matrix.
plt.show()
print(classification_report(y_test, y_test_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       1.00      0.40      0.57         5
#            2       0.78      0.75      0.76       522
#            3       0.55      0.41      0.47       674
#            4       0.00      0.00      0.00         3
#            5       0.52      0.68      0.59       162
#            6       0.27      0.16      0.20        86
#            7       0.73      0.83      0.78      1199
#            8       0.16      0.12      0.13        77
#            9       0.25      0.16      0.19        19
#           10       0.35      0.38      0.36       239
#           11       0.26      0.44      0.33        50
#           12       0.31      0.80      0.44         5
#           13       0.53      0.45      0.49        20
#           14       0.22      0.20      0.21        10
#           15       0.09      0.25      0.13        16
# ...

# %%
x
# Out:
#        level_0  index   pweight  nwspol  netusoft  netustm  polintr  trstsci  \
# 0            0      0  0.217716    80.0       1.0   6666.0      4.0      6.0
# 1            1      1  0.217716    63.0       5.0    180.0      1.0     10.0
# 2            2      2  0.217716   390.0       5.0    405.0      3.0      6.0
# 3            3      3  0.217716    60.0       5.0     80.0      4.0      3.0
# 4            4      4  0.217716   120.0       5.0    120.0      1.0      3.0
# ...        ...    ...       ...     ...       ...      ...      ...      ...
# 17935    18055  18055  0.323800   120.0       2.0   6666.0      4.0     10.0
# 17936    18056  18056  0.323800    90.0       4.0    120.0      2.0     10.0
# 17937    18057  18057  0.323800    30.0       2.0   6666.0      2.0      4.0
# 17938    18058  18058  0.323800    30.0       5.0     90.0      4.0      9.0
# 17939    18059  18059  0.323800    30.0       3.0   6666.0      4.0      8.0
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(criterion='gini',n_estimators=5,random_state=1,n_jobs=2)
#
# Fit the model
#
forest.fit(X_train, y_train)
#
# Measure model performance
#
y_pred = forest.predict(X_test)

# %%
cf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 8))
ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues',fmt="d")

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Category')
ax.set_ylabel('Actual Category ');


## Display the visualization of the Confusion Matrix.
plt.show()
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.10      0.20      0.13         5
#            2       0.57      0.79      0.66       522
#            3       0.33      0.39      0.36       674
#            4       0.00      0.00      0.00         3
#            5       0.49      0.52      0.51       162
#            6       0.11      0.12      0.11        86
#            7       0.69      0.72      0.71      1199
#            8       0.10      0.10      0.10        77
#            9       0.00      0.00      0.00        19
#           10       0.26      0.27      0.27       239
#           11       0.26      0.10      0.14        50
#           12       0.67      0.40      0.50         5
#           13       0.67      0.30      0.41        20
#           14       0.50      0.20      0.29        10
#           15       0.12      0.06      0.08        16
# ...
